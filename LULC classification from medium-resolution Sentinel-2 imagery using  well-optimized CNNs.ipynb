# %% [markdown]
# # Land Use and Land Cover Classification from Sentinel-2 imagery using Deep Convolutional Neural Networks

# %% [markdown]
# In this tutorial, we will perform the classification of Sentinel-2 multispectral images using well-optimized Convolutional Neural Networks (CNNs). The process involves training a well-optimized CNN model and subsequently applying the pre-trained model to map Land Use and Land Cover (LULC) in Sentinel-2 imagery. All the implementation will be carried out using Python programming within the Google Colab Pro environment, and the CNNs will be implemented using the Keras open-source Deep Learning library.

# %% [markdown]
# # Dataset Description

# %% [markdown]
# Five different LULC classes—settlement, barren land, fallow land, vegetation, and water bodies—are considered for classification of the Sentinel-2 composite images 4-band. For image classification, we employ a patch-based CNN approach, known for its superior performance compared to the pixel-based CNN method in terms of classification accuracy. The CNN patch size is determined based on the LULC features to be extracted from the satellite imagery. This includes considerations for their size, spatial structure, and the image's spatial resolution. A 5 * 5 pixel patch size was chosen due to the complex structure of LULC features. Moving forward, training data was collected. In total, 2400 training patches, and 600 testing patches of 5 * 5 pixel dimensions were extracted for each LULC class. These training patches were manually labeled through visual interpretation using high-resolution Google Earth imagery.

# %%
#import Google drive in Google Colab 
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#Setting up environment in Google Colab 

# import all necessary libraries for CNN model architecture and training 
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing import image
from keras.layers import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
from keras import optimizers

# %% [markdown]
# Now we will import the training and testing dataset from Google drive. Training and testing data is in numpy files. So, we will first import the numpy library.

# %%
#import training and testing dataset
import numpy as np
X_train=np.load('/content/gdrive/MyDrive/LULC_DCNN/Dataset/Training/training_features.npy')
y_train=np.load('/content/gdrive/MyDrive/LULC_DCNN/Dataset/Training/training_labels.npy')
X_test=np.load('/content/gdrive/MyDrive/LULC_DCNN/Dataset/Testing/testing_features.npy')
y_test=np.load('/content/gdrive/MyDrive/LULC_DCNN/Dataset/Testing/testing_labels.npy')

# %%
# Training and testing dataset shape

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (12000, 5, 5, 4) (12000,) (3000, 5, 5, 4) (3000,)

# %%
# Training and testing data type
print(X_train.dtype, y_train.dtype, X_test.dtype, y_test.dtype)
# Out:
# uint16 int32 uint16 int32

# %% [markdown]
# Now we will perform data normalization step. Data normalization ensures that input features are on a consistent scale, promoting stable training, faster convergence, and improved model generalization. It mitigates issues related to gradient descent, facilitates appropriate learning rate choices, and enhances the overall robustness of the model.

# %%
# Data Normalization of training and testing features
X_train=X_train/65535.0
X_test=X_test/65535.0

# %% [markdown]
# Now we will perform one-hot encoding vectors. One-hot encoding transforms categorical labels into binary vectors, where each unique category corresponds to a binary value, enabling the model to better understand and differentiate between different classes during training and prediction.

# %%
# Convert categorical labels into one-hot encoded vectors
from keras.utils import to_categorical
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# # Building and Training the well-optimized CNN

# %% [markdown]
# Now, this step is particularly crucial. We will design a well-optimized Convolutional Neural Network (CNN) architecture for classification, and proceed to train the model.

# %%
# Training the Deep Convolutional Neural Network (DCNN)
# DCNN architecture

learning_rate=0.0001
Adm =Adam(learning_rate)
SIZE=5
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=(2,2),strides=(1,1),padding='same', activation="relu", input_shape=(SIZE,SIZE,4)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=(2,2),strides=(1,1),padding='same', activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(2,2),strides=(1,1),padding='same', activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(5, activation="softmax"))
model.summary()

model.compile(optimizer=Adm, loss='categorical_crossentropy', metrics=['accuracy'])


history = model.fit(X_train, y_train, epochs=300,verbose=1, validation_data=(X_test, y_test), batch_size=128)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 5, 5, 16)          272
#
#  batch_normalization_1 (Bat  (None, 5, 5, 16)          64
#  chNormalization)
#
#  dropout (Dropout)           (None, 5, 5, 16)          0
#
#  conv2d_2 (Conv2D)           (None, 5, 5, 32)          2080
#
#  max_pooling2d (MaxPooling2  (None, 2, 2, 32)          0
#  D)
#
#  batch_normalization_2 (Bat  (None, 2, 2, 32)          128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 2, 2, 32)          0
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 64)          8256
#
#  max_pooling2d_1 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 1, 1, 64)          256
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 1, 1, 64)          0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 24181 (94.46 KB)
# Trainable params: 23957 (93.58 KB)
# Non-trainable params: 224 (896.00 Byte)
# _________________________________________________________________
# Epoch 1/300
# 94/94 [==============================] - 6s 19ms/step - loss: 1.5404 - accuracy: 0.3594 - val_loss: 1.6291 - val_accuracy: 0.2000
# Epoch 2/300
# 94/94 [==============================] - 1s 15ms/step - loss: 1.0590 - accuracy: 0.5657 - val_loss: 1.7469 - val_accuracy: 0.3043
# Epoch 3/300
# 94/94 [==============================] - 2s 17ms/step - loss: 0.7971 - accuracy: 0.6862 - val_loss: 2.0061 - val_accuracy: 0.2110
# Epoch 4/300
# 94/94 [==============================] - 2s 17ms/step - loss: 0.6578 - accuracy: 0.7408 - val_loss: 2.2235 - val_accuracy: 0.2000
# Epoch 5/300
# 94/94 [==============================] - 1s 11ms/step - loss: 0.5611 - accuracy: 0.7837 - val_loss: 2.3026 - val_accuracy: 0.2000
# Epoch 6/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4830 - accuracy: 0.8163 - val_loss: 1.8906 - val_accuracy: 0.2097
# Epoch 7/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4242 - accuracy: 0.8508 - val_loss: 0.9850 - val_accuracy: 0.5657
# Epoch 8/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.3691 - accuracy: 0.8702 - val_loss: 0.5217 - val_accuracy: 0.7830
# Epoch 9/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.3339 - accuracy: 0.8881 - val_loss: 0.3649 - val_accuracy: 0.8657
# Epoch 10/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.3049 - accuracy: 0.9000 - val_loss: 0.2660 - val_accuracy: 0.9143
# Epoch 11/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2809 - accuracy: 0.9123 - val_loss: 0.2537 - val_accuracy: 0.9170
# Epoch 12/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2688 - accuracy: 0.9178 - val_loss: 0.2398 - val_accuracy: 0.9180
# Epoch 13/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2507 - accuracy: 0.9180 - val_loss: 0.2663 - val_accuracy: 0.9060
# Epoch 14/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2377 - accuracy: 0.9262 - val_loss: 0.2204 - val_accuracy: 0.9233
# Epoch 15/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2294 - accuracy: 0.9298 - val_loss: 0.2408 - val_accuracy: 0.9183
# Epoch 16/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2197 - accuracy: 0.9333 - val_loss: 0.2594 - val_accuracy: 0.9137
# Epoch 17/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2111 - accuracy: 0.9389 - val_loss: 0.2285 - val_accuracy: 0.9120
# Epoch 18/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.2030 - accuracy: 0.9368 - val_loss: 0.2488 - val_accuracy: 0.9013
# Epoch 19/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.2017 - accuracy: 0.9388 - val_loss: 0.3036 - val_accuracy: 0.8830
# Epoch 20/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.1942 - accuracy: 0.9420 - val_loss: 0.2345 - val_accuracy: 0.9107
# Epoch 21/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1981 - accuracy: 0.9414 - val_loss: 0.2240 - val_accuracy: 0.9167
# Epoch 22/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.1865 - accuracy: 0.9429 - val_loss: 0.2622 - val_accuracy: 0.8970
# Epoch 23/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1888 - accuracy: 0.9435 - val_loss: 0.2517 - val_accuracy: 0.8997
# Epoch 24/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1822 - accuracy: 0.9461 - val_loss: 0.2470 - val_accuracy: 0.9030
# Epoch 25/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1739 - accuracy: 0.9488 - val_loss: 0.2172 - val_accuracy: 0.9220
# Epoch 26/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1793 - accuracy: 0.9451 - val_loss: 0.2208 - val_accuracy: 0.9160
# Epoch 27/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1710 - accuracy: 0.9511 - val_loss: 0.2809 - val_accuracy: 0.8793
# Epoch 28/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1679 - accuracy: 0.9492 - val_loss: 0.2098 - val_accuracy: 0.9210
# Epoch 29/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1578 - accuracy: 0.9531 - val_loss: 0.1929 - val_accuracy: 0.9287
# Epoch 30/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1533 - accuracy: 0.9525 - val_loss: 0.2275 - val_accuracy: 0.9127
# Epoch 31/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1610 - accuracy: 0.9508 - val_loss: 0.2535 - val_accuracy: 0.9007
# Epoch 32/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1581 - accuracy: 0.9533 - val_loss: 0.2019 - val_accuracy: 0.9200
# Epoch 33/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1546 - accuracy: 0.9535 - val_loss: 0.2154 - val_accuracy: 0.9153
# Epoch 34/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1548 - accuracy: 0.9536 - val_loss: 0.1890 - val_accuracy: 0.9280
# Epoch 35/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1471 - accuracy: 0.9567 - val_loss: 0.2423 - val_accuracy: 0.9063
# Epoch 36/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1396 - accuracy: 0.9580 - val_loss: 0.2130 - val_accuracy: 0.9090
# Epoch 37/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1402 - accuracy: 0.9567 - val_loss: 0.2031 - val_accuracy: 0.9200
# Epoch 38/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1469 - accuracy: 0.9546 - val_loss: 0.2361 - val_accuracy: 0.9013
# Epoch 39/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1385 - accuracy: 0.9573 - val_loss: 0.3471 - val_accuracy: 0.8573
# Epoch 40/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1419 - accuracy: 0.9576 - val_loss: 0.1704 - val_accuracy: 0.9257
# Epoch 41/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1415 - accuracy: 0.9565 - val_loss: 0.2087 - val_accuracy: 0.9100
# Epoch 42/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1368 - accuracy: 0.9581 - val_loss: 0.2432 - val_accuracy: 0.8923
# Epoch 43/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1324 - accuracy: 0.9601 - val_loss: 0.2460 - val_accuracy: 0.9000
# Epoch 44/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1272 - accuracy: 0.9603 - val_loss: 0.5271 - val_accuracy: 0.8073
# Epoch 45/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1283 - accuracy: 0.9609 - val_loss: 0.2234 - val_accuracy: 0.8963
# Epoch 46/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1226 - accuracy: 0.9629 - val_loss: 0.1259 - val_accuracy: 0.9550
# Epoch 47/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1217 - accuracy: 0.9633 - val_loss: 0.2140 - val_accuracy: 0.9170
# Epoch 48/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1214 - accuracy: 0.9642 - val_loss: 0.1831 - val_accuracy: 0.9280
# Epoch 49/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1222 - accuracy: 0.9635 - val_loss: 0.1892 - val_accuracy: 0.9223
# Epoch 50/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1228 - accuracy: 0.9617 - val_loss: 0.1359 - val_accuracy: 0.9413
# Epoch 51/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1188 - accuracy: 0.9631 - val_loss: 0.1944 - val_accuracy: 0.9300
# Epoch 52/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1171 - accuracy: 0.9651 - val_loss: 0.2163 - val_accuracy: 0.9160
# Epoch 53/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.1156 - accuracy: 0.9638 - val_loss: 0.1384 - val_accuracy: 0.9390
# Epoch 54/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1087 - accuracy: 0.9676 - val_loss: 0.1734 - val_accuracy: 0.9260
# Epoch 55/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1119 - accuracy: 0.9666 - val_loss: 0.2203 - val_accuracy: 0.9083
# Epoch 56/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1084 - accuracy: 0.9676 - val_loss: 0.1222 - val_accuracy: 0.9493
# Epoch 57/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1122 - accuracy: 0.9675 - val_loss: 0.1308 - val_accuracy: 0.9460
# Epoch 58/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1066 - accuracy: 0.9678 - val_loss: 0.0983 - val_accuracy: 0.9623
# Epoch 59/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1010 - accuracy: 0.9693 - val_loss: 0.1052 - val_accuracy: 0.9640
# Epoch 60/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1074 - accuracy: 0.9682 - val_loss: 0.2205 - val_accuracy: 0.9043
# Epoch 61/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0991 - accuracy: 0.9689 - val_loss: 0.1769 - val_accuracy: 0.9330
# Epoch 62/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1015 - accuracy: 0.9695 - val_loss: 0.0741 - val_accuracy: 0.9763
# Epoch 63/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.1021 - accuracy: 0.9703 - val_loss: 0.0855 - val_accuracy: 0.9670
# Epoch 64/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.1007 - accuracy: 0.9698 - val_loss: 0.1930 - val_accuracy: 0.9240
# Epoch 65/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0999 - accuracy: 0.9716 - val_loss: 0.1860 - val_accuracy: 0.9237
# Epoch 66/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0941 - accuracy: 0.9726 - val_loss: 0.1761 - val_accuracy: 0.9273
# Epoch 67/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0946 - accuracy: 0.9714 - val_loss: 0.1044 - val_accuracy: 0.9583
# Epoch 68/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0968 - accuracy: 0.9719 - val_loss: 0.1308 - val_accuracy: 0.9480
# Epoch 69/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0913 - accuracy: 0.9728 - val_loss: 0.1030 - val_accuracy: 0.9597
# Epoch 70/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0890 - accuracy: 0.9732 - val_loss: 0.1296 - val_accuracy: 0.9463
# Epoch 71/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0856 - accuracy: 0.9747 - val_loss: 0.0985 - val_accuracy: 0.9560
# Epoch 72/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0803 - accuracy: 0.9759 - val_loss: 0.1645 - val_accuracy: 0.9343
# Epoch 73/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0833 - accuracy: 0.9743 - val_loss: 0.1720 - val_accuracy: 0.9370
# Epoch 74/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0823 - accuracy: 0.9747 - val_loss: 0.0694 - val_accuracy: 0.9753
# Epoch 75/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0882 - accuracy: 0.9742 - val_loss: 0.0856 - val_accuracy: 0.9650
# Epoch 76/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0766 - accuracy: 0.9783 - val_loss: 0.0768 - val_accuracy: 0.9693
# Epoch 77/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0772 - accuracy: 0.9759 - val_loss: 0.1103 - val_accuracy: 0.9547
# Epoch 78/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0749 - accuracy: 0.9774 - val_loss: 0.0684 - val_accuracy: 0.9777
# Epoch 79/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0787 - accuracy: 0.9772 - val_loss: 0.1061 - val_accuracy: 0.9593
# Epoch 80/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0723 - accuracy: 0.9802 - val_loss: 0.0945 - val_accuracy: 0.9603
# Epoch 81/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0774 - accuracy: 0.9783 - val_loss: 0.1509 - val_accuracy: 0.9367
# Epoch 82/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0766 - accuracy: 0.9770 - val_loss: 0.0930 - val_accuracy: 0.9630
# Epoch 83/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0760 - accuracy: 0.9789 - val_loss: 0.1520 - val_accuracy: 0.9410
# Epoch 84/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0692 - accuracy: 0.9789 - val_loss: 0.2229 - val_accuracy: 0.9147
# Epoch 85/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0756 - accuracy: 0.9782 - val_loss: 0.2337 - val_accuracy: 0.9163
# Epoch 86/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0706 - accuracy: 0.9796 - val_loss: 0.1415 - val_accuracy: 0.9427
# Epoch 87/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0731 - accuracy: 0.9780 - val_loss: 0.0744 - val_accuracy: 0.9697
# Epoch 88/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0719 - accuracy: 0.9789 - val_loss: 0.1189 - val_accuracy: 0.9533
# Epoch 89/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0756 - accuracy: 0.9777 - val_loss: 0.0753 - val_accuracy: 0.9723
# Epoch 90/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0704 - accuracy: 0.9800 - val_loss: 0.0461 - val_accuracy: 0.9873
# Epoch 91/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0720 - accuracy: 0.9792 - val_loss: 0.0366 - val_accuracy: 0.9887
# Epoch 92/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0649 - accuracy: 0.9810 - val_loss: 0.0335 - val_accuracy: 0.9933
# Epoch 93/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0626 - accuracy: 0.9811 - val_loss: 0.0494 - val_accuracy: 0.9823
# Epoch 94/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0621 - accuracy: 0.9827 - val_loss: 0.0715 - val_accuracy: 0.9713
# Epoch 95/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0643 - accuracy: 0.9797 - val_loss: 0.0438 - val_accuracy: 0.9833
# Epoch 96/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0652 - accuracy: 0.9818 - val_loss: 0.1019 - val_accuracy: 0.9593
# Epoch 97/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0667 - accuracy: 0.9812 - val_loss: 0.1084 - val_accuracy: 0.9573
# Epoch 98/300
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0608 - accuracy: 0.9813 - val_loss: 0.1966 - val_accuracy: 0.9350
# Epoch 99/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0587 - accuracy: 0.9828 - val_loss: 0.1107 - val_accuracy: 0.9573
# Epoch 100/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0654 - accuracy: 0.9811 - val_loss: 0.0265 - val_accuracy: 0.9920
# Epoch 101/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0649 - accuracy: 0.9816 - val_loss: 0.0326 - val_accuracy: 0.9937
# Epoch 102/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0594 - accuracy: 0.9824 - val_loss: 0.0675 - val_accuracy: 0.9727
# Epoch 103/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0619 - accuracy: 0.9818 - val_loss: 0.0489 - val_accuracy: 0.9827
# Epoch 104/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0664 - accuracy: 0.9813 - val_loss: 0.1036 - val_accuracy: 0.9573
# Epoch 105/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0578 - accuracy: 0.9839 - val_loss: 0.0515 - val_accuracy: 0.9800
# Epoch 106/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0551 - accuracy: 0.9845 - val_loss: 0.0570 - val_accuracy: 0.9773
# Epoch 107/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0576 - accuracy: 0.9822 - val_loss: 0.1013 - val_accuracy: 0.9637
# Epoch 108/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0560 - accuracy: 0.9834 - val_loss: 0.0600 - val_accuracy: 0.9753
# Epoch 109/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0560 - accuracy: 0.9847 - val_loss: 0.0674 - val_accuracy: 0.9747
# Epoch 110/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0565 - accuracy: 0.9829 - val_loss: 0.0596 - val_accuracy: 0.9750
# Epoch 111/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0587 - accuracy: 0.9838 - val_loss: 0.0886 - val_accuracy: 0.9653
# Epoch 112/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0549 - accuracy: 0.9843 - val_loss: 0.0338 - val_accuracy: 0.9890
# Epoch 113/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0527 - accuracy: 0.9846 - val_loss: 0.0853 - val_accuracy: 0.9660
# Epoch 114/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0519 - accuracy: 0.9850 - val_loss: 0.0776 - val_accuracy: 0.9720
# Epoch 115/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0596 - accuracy: 0.9833 - val_loss: 0.1081 - val_accuracy: 0.9563
# Epoch 116/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0495 - accuracy: 0.9849 - val_loss: 0.0248 - val_accuracy: 0.9923
# Epoch 117/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0572 - accuracy: 0.9822 - val_loss: 0.0447 - val_accuracy: 0.9803
# Epoch 118/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0547 - accuracy: 0.9831 - val_loss: 0.0745 - val_accuracy: 0.9707
# Epoch 119/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0562 - accuracy: 0.9838 - val_loss: 0.0476 - val_accuracy: 0.9810
# Epoch 120/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0542 - accuracy: 0.9844 - val_loss: 0.0958 - val_accuracy: 0.9633
# Epoch 121/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0513 - accuracy: 0.9840 - val_loss: 0.0205 - val_accuracy: 0.9953
# Epoch 122/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0488 - accuracy: 0.9852 - val_loss: 0.0332 - val_accuracy: 0.9893
# Epoch 123/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0523 - accuracy: 0.9844 - val_loss: 0.0201 - val_accuracy: 0.9947
# Epoch 124/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0497 - accuracy: 0.9847 - val_loss: 0.0497 - val_accuracy: 0.9803
# Epoch 125/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0529 - accuracy: 0.9847 - val_loss: 0.0618 - val_accuracy: 0.9743
# Epoch 126/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0516 - accuracy: 0.9850 - val_loss: 0.1239 - val_accuracy: 0.9540
# Epoch 127/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0551 - accuracy: 0.9831 - val_loss: 0.0373 - val_accuracy: 0.9860
# Epoch 128/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0512 - accuracy: 0.9841 - val_loss: 0.1097 - val_accuracy: 0.9577
# Epoch 129/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0505 - accuracy: 0.9860 - val_loss: 0.0322 - val_accuracy: 0.9867
# Epoch 130/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0436 - accuracy: 0.9870 - val_loss: 0.0273 - val_accuracy: 0.9877
# Epoch 131/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0570 - accuracy: 0.9843 - val_loss: 0.0238 - val_accuracy: 0.9897
# Epoch 132/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0532 - accuracy: 0.9850 - val_loss: 0.1254 - val_accuracy: 0.9530
# Epoch 133/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0451 - accuracy: 0.9871 - val_loss: 0.0441 - val_accuracy: 0.9813
# Epoch 134/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0483 - accuracy: 0.9858 - val_loss: 0.0269 - val_accuracy: 0.9887
# Epoch 135/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0473 - accuracy: 0.9857 - val_loss: 0.0278 - val_accuracy: 0.9930
# Epoch 136/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0470 - accuracy: 0.9854 - val_loss: 0.0835 - val_accuracy: 0.9673
# Epoch 137/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0482 - accuracy: 0.9848 - val_loss: 0.0339 - val_accuracy: 0.9863
# Epoch 138/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0523 - accuracy: 0.9847 - val_loss: 0.0996 - val_accuracy: 0.9623
# Epoch 139/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0491 - accuracy: 0.9854 - val_loss: 0.0229 - val_accuracy: 0.9903
# Epoch 140/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0491 - accuracy: 0.9862 - val_loss: 0.0527 - val_accuracy: 0.9760
# Epoch 141/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0443 - accuracy: 0.9856 - val_loss: 0.0234 - val_accuracy: 0.9913
# Epoch 142/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0465 - accuracy: 0.9851 - val_loss: 0.0367 - val_accuracy: 0.9860
# Epoch 143/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0487 - accuracy: 0.9856 - val_loss: 0.0239 - val_accuracy: 0.9937
# Epoch 144/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0514 - accuracy: 0.9852 - val_loss: 0.0350 - val_accuracy: 0.9833
# Epoch 145/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0484 - accuracy: 0.9860 - val_loss: 0.0519 - val_accuracy: 0.9780
# Epoch 146/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0446 - accuracy: 0.9863 - val_loss: 0.0417 - val_accuracy: 0.9810
# Epoch 147/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0440 - accuracy: 0.9869 - val_loss: 0.0209 - val_accuracy: 0.9937
# Epoch 148/300
# 94/94 [==============================] - 1s 11ms/step - loss: 0.0459 - accuracy: 0.9867 - val_loss: 0.0380 - val_accuracy: 0.9830
# Epoch 149/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0458 - accuracy: 0.9871 - val_loss: 0.0390 - val_accuracy: 0.9830
# Epoch 150/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0453 - accuracy: 0.9873 - val_loss: 0.0682 - val_accuracy: 0.9723
# Epoch 151/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0463 - accuracy: 0.9868 - val_loss: 0.0348 - val_accuracy: 0.9877
# Epoch 152/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0403 - accuracy: 0.9874 - val_loss: 0.0277 - val_accuracy: 0.9910
# Epoch 153/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0453 - accuracy: 0.9861 - val_loss: 0.0732 - val_accuracy: 0.9693
# Epoch 154/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0464 - accuracy: 0.9863 - val_loss: 0.0281 - val_accuracy: 0.9883
# Epoch 155/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0471 - accuracy: 0.9868 - val_loss: 0.0295 - val_accuracy: 0.9880
# Epoch 156/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0471 - accuracy: 0.9865 - val_loss: 0.0551 - val_accuracy: 0.9777
# Epoch 157/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0424 - accuracy: 0.9871 - val_loss: 0.0943 - val_accuracy: 0.9643
# Epoch 158/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0421 - accuracy: 0.9880 - val_loss: 0.1177 - val_accuracy: 0.9577
# Epoch 159/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0434 - accuracy: 0.9858 - val_loss: 0.0359 - val_accuracy: 0.9830
# Epoch 160/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0427 - accuracy: 0.9877 - val_loss: 0.0449 - val_accuracy: 0.9793
# Epoch 161/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0476 - accuracy: 0.9861 - val_loss: 0.0653 - val_accuracy: 0.9737
# Epoch 162/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0401 - accuracy: 0.9884 - val_loss: 0.0544 - val_accuracy: 0.9797
# Epoch 163/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0442 - accuracy: 0.9867 - val_loss: 0.0880 - val_accuracy: 0.9663
# Epoch 164/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0405 - accuracy: 0.9878 - val_loss: 0.2095 - val_accuracy: 0.9370
# Epoch 165/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0447 - accuracy: 0.9853 - val_loss: 0.0835 - val_accuracy: 0.9670
# Epoch 166/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0427 - accuracy: 0.9868 - val_loss: 0.0855 - val_accuracy: 0.9660
# Epoch 167/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0440 - accuracy: 0.9865 - val_loss: 0.0362 - val_accuracy: 0.9833
# Epoch 168/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0451 - accuracy: 0.9869 - val_loss: 0.1132 - val_accuracy: 0.9570
# Epoch 169/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0404 - accuracy: 0.9882 - val_loss: 0.0432 - val_accuracy: 0.9813
# Epoch 170/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0410 - accuracy: 0.9877 - val_loss: 0.0318 - val_accuracy: 0.9850
# Epoch 171/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0415 - accuracy: 0.9880 - val_loss: 0.0412 - val_accuracy: 0.9830
# Epoch 172/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0394 - accuracy: 0.9875 - val_loss: 0.0203 - val_accuracy: 0.9940
# Epoch 173/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0423 - accuracy: 0.9868 - val_loss: 0.0195 - val_accuracy: 0.9957
# Epoch 174/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0421 - accuracy: 0.9872 - val_loss: 0.0280 - val_accuracy: 0.9883
# Epoch 175/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0441 - accuracy: 0.9875 - val_loss: 0.0228 - val_accuracy: 0.9943
# Epoch 176/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0365 - accuracy: 0.9889 - val_loss: 0.0157 - val_accuracy: 0.9977
# Epoch 177/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0426 - accuracy: 0.9868 - val_loss: 0.0193 - val_accuracy: 0.9937
# Epoch 178/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0375 - accuracy: 0.9880 - val_loss: 0.0316 - val_accuracy: 0.9853
# Epoch 179/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0411 - accuracy: 0.9877 - val_loss: 0.0330 - val_accuracy: 0.9840
# Epoch 180/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0415 - accuracy: 0.9885 - val_loss: 0.0190 - val_accuracy: 0.9950
# Epoch 181/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0403 - accuracy: 0.9876 - val_loss: 0.0364 - val_accuracy: 0.9847
# Epoch 182/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0368 - accuracy: 0.9899 - val_loss: 0.0159 - val_accuracy: 0.9970
# Epoch 183/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0365 - accuracy: 0.9891 - val_loss: 0.0372 - val_accuracy: 0.9850
# Epoch 184/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 0.0315 - val_accuracy: 0.9893
# Epoch 185/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0438 - accuracy: 0.9878 - val_loss: 0.1349 - val_accuracy: 0.9400
# Epoch 186/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0358 - accuracy: 0.9890 - val_loss: 0.0166 - val_accuracy: 0.9973
# Epoch 187/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0369 - accuracy: 0.9885 - val_loss: 0.0495 - val_accuracy: 0.9780
# Epoch 188/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.0364 - val_accuracy: 0.9837
# Epoch 189/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0347 - accuracy: 0.9891 - val_loss: 0.2262 - val_accuracy: 0.9317
# Epoch 190/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0382 - accuracy: 0.9884 - val_loss: 0.0132 - val_accuracy: 0.9970
# Epoch 191/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0401 - accuracy: 0.9883 - val_loss: 0.0547 - val_accuracy: 0.9747
# Epoch 192/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0413 - accuracy: 0.9875 - val_loss: 0.0214 - val_accuracy: 0.9913
# Epoch 193/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0401 - accuracy: 0.9885 - val_loss: 0.0553 - val_accuracy: 0.9770
# Epoch 194/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0359 - accuracy: 0.9895 - val_loss: 0.0341 - val_accuracy: 0.9847
# Epoch 195/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0373 - accuracy: 0.9890 - val_loss: 0.2493 - val_accuracy: 0.8960
# Epoch 196/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0322 - accuracy: 0.9903 - val_loss: 0.0213 - val_accuracy: 0.9923
# Epoch 197/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0370 - accuracy: 0.9892 - val_loss: 0.0368 - val_accuracy: 0.9867
# Epoch 198/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0386 - accuracy: 0.9880 - val_loss: 0.0611 - val_accuracy: 0.9733
# Epoch 199/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0390 - accuracy: 0.9886 - val_loss: 0.0229 - val_accuracy: 0.9920
# Epoch 200/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0369 - accuracy: 0.9886 - val_loss: 0.0200 - val_accuracy: 0.9930
# Epoch 201/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0351 - accuracy: 0.9898 - val_loss: 0.0453 - val_accuracy: 0.9807
# Epoch 202/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0355 - accuracy: 0.9890 - val_loss: 0.0218 - val_accuracy: 0.9897
# Epoch 203/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0394 - accuracy: 0.9882 - val_loss: 0.0365 - val_accuracy: 0.9863
# Epoch 204/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0398 - accuracy: 0.9892 - val_loss: 0.0526 - val_accuracy: 0.9790
# Epoch 205/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0357 - accuracy: 0.9891 - val_loss: 0.0193 - val_accuracy: 0.9967
# Epoch 206/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0369 - accuracy: 0.9890 - val_loss: 0.0277 - val_accuracy: 0.9910
# Epoch 207/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0355 - accuracy: 0.9894 - val_loss: 0.0860 - val_accuracy: 0.9680
# Epoch 208/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0390 - accuracy: 0.9884 - val_loss: 0.0292 - val_accuracy: 0.9853
# Epoch 209/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0382 - accuracy: 0.9898 - val_loss: 0.0239 - val_accuracy: 0.9903
# Epoch 210/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.0160 - val_accuracy: 0.9977
# Epoch 211/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0338 - accuracy: 0.9904 - val_loss: 0.1004 - val_accuracy: 0.9610
# Epoch 212/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0337 - accuracy: 0.9894 - val_loss: 0.0415 - val_accuracy: 0.9810
# Epoch 213/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0389 - accuracy: 0.9898 - val_loss: 0.0368 - val_accuracy: 0.9847
# Epoch 214/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0320 - accuracy: 0.9904 - val_loss: 0.0282 - val_accuracy: 0.9867
# Epoch 215/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0317 - accuracy: 0.9903 - val_loss: 0.0274 - val_accuracy: 0.9870
# Epoch 216/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0351 - accuracy: 0.9898 - val_loss: 0.0199 - val_accuracy: 0.9930
# Epoch 217/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0359 - accuracy: 0.9896 - val_loss: 0.0250 - val_accuracy: 0.9887
# Epoch 218/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0321 - accuracy: 0.9896 - val_loss: 0.0460 - val_accuracy: 0.9787
# Epoch 219/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0383 - accuracy: 0.9885 - val_loss: 0.0197 - val_accuracy: 0.9907
# Epoch 220/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0324 - accuracy: 0.9898 - val_loss: 0.0533 - val_accuracy: 0.9787
# Epoch 221/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0362 - accuracy: 0.9890 - val_loss: 0.0669 - val_accuracy: 0.9733
# Epoch 222/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0370 - accuracy: 0.9884 - val_loss: 0.0555 - val_accuracy: 0.9827
# Epoch 223/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0349 - accuracy: 0.9891 - val_loss: 0.0298 - val_accuracy: 0.9860
# Epoch 224/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0319 - accuracy: 0.9903 - val_loss: 0.0497 - val_accuracy: 0.9803
# Epoch 225/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0305 - accuracy: 0.9907 - val_loss: 0.0256 - val_accuracy: 0.9887
# Epoch 226/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.0357 - val_accuracy: 0.9843
# Epoch 227/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0307 - accuracy: 0.9909 - val_loss: 0.0243 - val_accuracy: 0.9893
# Epoch 228/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0308 - accuracy: 0.9911 - val_loss: 0.0662 - val_accuracy: 0.9753
# Epoch 229/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0305 - accuracy: 0.9907 - val_loss: 0.0185 - val_accuracy: 0.9920
# Epoch 230/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0358 - accuracy: 0.9893 - val_loss: 0.0328 - val_accuracy: 0.9867
# Epoch 231/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0341 - accuracy: 0.9890 - val_loss: 0.0243 - val_accuracy: 0.9883
# Epoch 232/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0315 - accuracy: 0.9901 - val_loss: 0.0858 - val_accuracy: 0.9660
# Epoch 233/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0303 - accuracy: 0.9910 - val_loss: 0.0284 - val_accuracy: 0.9863
# Epoch 234/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0359 - accuracy: 0.9891 - val_loss: 0.0193 - val_accuracy: 0.9963
# Epoch 235/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 0.0105 - val_accuracy: 0.9983
# Epoch 236/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0353 - accuracy: 0.9901 - val_loss: 0.0476 - val_accuracy: 0.9813
# Epoch 237/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.0262 - val_accuracy: 0.9880
# Epoch 238/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0351 - accuracy: 0.9897 - val_loss: 0.0211 - val_accuracy: 0.9900
# Epoch 239/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0317 - accuracy: 0.9902 - val_loss: 0.0249 - val_accuracy: 0.9927
# Epoch 240/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0327 - accuracy: 0.9892 - val_loss: 0.0114 - val_accuracy: 0.9970
# Epoch 241/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0321 - accuracy: 0.9898 - val_loss: 0.0668 - val_accuracy: 0.9730
# Epoch 242/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0323 - accuracy: 0.9897 - val_loss: 0.0211 - val_accuracy: 0.9923
# Epoch 243/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0335 - accuracy: 0.9895 - val_loss: 0.0312 - val_accuracy: 0.9853
# Epoch 244/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0337 - accuracy: 0.9901 - val_loss: 0.0528 - val_accuracy: 0.9793
# Epoch 245/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0324 - accuracy: 0.9898 - val_loss: 0.0606 - val_accuracy: 0.9787
# Epoch 246/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0368 - accuracy: 0.9893 - val_loss: 0.0229 - val_accuracy: 0.9953
# Epoch 247/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0301 - accuracy: 0.9908 - val_loss: 0.0251 - val_accuracy: 0.9890
# Epoch 248/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0334 - accuracy: 0.9899 - val_loss: 0.0397 - val_accuracy: 0.9817
# Epoch 249/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0334 - accuracy: 0.9897 - val_loss: 0.0132 - val_accuracy: 0.9967
# Epoch 250/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9918 - val_loss: 0.0229 - val_accuracy: 0.9907
# Epoch 251/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0306 - accuracy: 0.9900 - val_loss: 0.0392 - val_accuracy: 0.9817
# Epoch 252/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0298 - accuracy: 0.9906 - val_loss: 0.0203 - val_accuracy: 0.9917
# Epoch 253/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.0246 - val_accuracy: 0.9897
# Epoch 254/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0329 - accuracy: 0.9906 - val_loss: 0.0451 - val_accuracy: 0.9817
# Epoch 255/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0363 - accuracy: 0.9891 - val_loss: 0.0218 - val_accuracy: 0.9920
# Epoch 256/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0301 - accuracy: 0.9902 - val_loss: 0.0404 - val_accuracy: 0.9837
# Epoch 257/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0340 - accuracy: 0.9893 - val_loss: 0.0412 - val_accuracy: 0.9827
# Epoch 258/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0324 - accuracy: 0.9905 - val_loss: 0.0508 - val_accuracy: 0.9790
# Epoch 259/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0286 - accuracy: 0.9912 - val_loss: 0.0410 - val_accuracy: 0.9837
# Epoch 260/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0303 - accuracy: 0.9916 - val_loss: 0.0272 - val_accuracy: 0.9883
# Epoch 261/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0309 - accuracy: 0.9906 - val_loss: 0.0154 - val_accuracy: 0.9967
# Epoch 262/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0283 - accuracy: 0.9919 - val_loss: 0.0152 - val_accuracy: 0.9947
# Epoch 263/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0327 - val_accuracy: 0.9857
# Epoch 264/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0370 - accuracy: 0.9891 - val_loss: 0.0117 - val_accuracy: 0.9983
# Epoch 265/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0306 - accuracy: 0.9912 - val_loss: 0.0410 - val_accuracy: 0.9797
# Epoch 266/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.0196 - val_accuracy: 0.9937
# Epoch 267/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.0318 - val_accuracy: 0.9850
# Epoch 268/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0273 - accuracy: 0.9917 - val_loss: 0.0986 - val_accuracy: 0.9630
# Epoch 269/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0313 - accuracy: 0.9916 - val_loss: 0.0182 - val_accuracy: 0.9927
# Epoch 270/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0264 - accuracy: 0.9917 - val_loss: 0.0140 - val_accuracy: 0.9980
# Epoch 271/300
# 94/94 [==============================] - 1s 8ms/step - loss: 0.0257 - accuracy: 0.9916 - val_loss: 0.0151 - val_accuracy: 0.9960
# Epoch 272/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0300 - accuracy: 0.9903 - val_loss: 0.0212 - val_accuracy: 0.9903
# Epoch 273/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0369 - accuracy: 0.9887 - val_loss: 0.0320 - val_accuracy: 0.9860
# Epoch 274/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0268 - accuracy: 0.9924 - val_loss: 0.0141 - val_accuracy: 0.9977
# Epoch 275/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0301 - accuracy: 0.9915 - val_loss: 0.0139 - val_accuracy: 0.9987
# Epoch 276/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0304 - accuracy: 0.9908 - val_loss: 0.0536 - val_accuracy: 0.9773
# Epoch 277/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0286 - accuracy: 0.9912 - val_loss: 0.0156 - val_accuracy: 0.9950
# Epoch 278/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0281 - accuracy: 0.9912 - val_loss: 0.0115 - val_accuracy: 0.9977
# Epoch 279/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0265 - accuracy: 0.9921 - val_loss: 0.0117 - val_accuracy: 0.9980
# Epoch 280/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0277 - accuracy: 0.9914 - val_loss: 0.0335 - val_accuracy: 0.9873
# Epoch 281/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0284 - accuracy: 0.9913 - val_loss: 0.0154 - val_accuracy: 0.9947
# Epoch 282/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0275 - accuracy: 0.9911 - val_loss: 0.0493 - val_accuracy: 0.9840
# Epoch 283/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0269 - accuracy: 0.9914 - val_loss: 0.0548 - val_accuracy: 0.9783
# Epoch 284/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.0260 - val_accuracy: 0.9893
# Epoch 285/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0264 - accuracy: 0.9916 - val_loss: 0.0151 - val_accuracy: 0.9977
# Epoch 286/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0275 - accuracy: 0.9915 - val_loss: 0.0107 - val_accuracy: 0.9987
# Epoch 287/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0262 - accuracy: 0.9922 - val_loss: 0.0160 - val_accuracy: 0.9987
# Epoch 288/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0315 - accuracy: 0.9900 - val_loss: 0.0160 - val_accuracy: 0.9930
# Epoch 289/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0280 - accuracy: 0.9909 - val_loss: 0.1528 - val_accuracy: 0.9593
# Epoch 290/300
# 94/94 [==============================] - 1s 6ms/step - loss: 0.0265 - accuracy: 0.9915 - val_loss: 0.0168 - val_accuracy: 0.9933
# Epoch 291/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0280 - accuracy: 0.9916 - val_loss: 0.0316 - val_accuracy: 0.9863
# Epoch 292/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.0305 - val_accuracy: 0.9870
# Epoch 293/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0298 - accuracy: 0.9915 - val_loss: 0.0690 - val_accuracy: 0.9727
# Epoch 294/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.0148 - val_accuracy: 0.9933
# Epoch 295/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0282 - accuracy: 0.9914 - val_loss: 0.0152 - val_accuracy: 0.9940
# Epoch 296/300
# 94/94 [==============================] - 1s 9ms/step - loss: 0.0262 - accuracy: 0.9909 - val_loss: 0.0239 - val_accuracy: 0.9917
# Epoch 297/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0263 - accuracy: 0.9926 - val_loss: 0.0256 - val_accuracy: 0.9880
# Epoch 298/300
# 94/94 [==============================] - 1s 10ms/step - loss: 0.0319 - accuracy: 0.9907 - val_loss: 0.0154 - val_accuracy: 0.9940
# Epoch 299/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0263 - accuracy: 0.9922 - val_loss: 0.0368 - val_accuracy: 0.9853
# Epoch 300/300
# 94/94 [==============================] - 1s 7ms/step - loss: 0.0321 - accuracy: 0.9901 - val_loss: 0.0125 - val_accuracy: 0.9970

# %% [markdown]
# # Save Trained CNN model in directory

# %% [markdown]
# As we have trained the CNN model, we will now save it in our directory. Since we are performing classification in Google Colab, we will save our trained model in Google Drive

# %%
# Save trained DCNN model
model.save('/content/gdrive/MyDrive/LULC_DCNN/4bands_DCNN_LULCclassification.h5')

# %% [markdown]
# # Load saved CNN model

# %%
# Load saved trained DCNN model
from keras.models import load_model
model_load = load_model('/content/gdrive/MyDrive/LULC_DCNN/4bands_DCNN_LULCclassification.h5')

# %% [markdown]
# Let's generate confusion matrices for the training and testing datasets. To do this, we'll first convert the training and testing labels into class indices. Converting back to class indices simplifies the comparison of model predictions with ground truth labels during evaluation or analysis. This enables a direct comparison between the predicted class (an index) and the true class label, facilitating the calculation of metrics such as accuracy, precision, and recall. Such conversion is particularly valuable when interpreting and presenting classification results

# %%
#Training data confusion matrix
# convert the one-hot encoded labels (y_train) into class indices
train_labels=np.argmax(y_train, axis=1)
predict_x=model_load.predict(X_train)
classes_x=np.argmax(predict_x,axis=1)
# Out:
# 375/375 [==============================] - 1s 3ms/step

# %%
# import necessary libraries for training data confusion matrix
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# Training data confusion matrix

confusion_matrix=confusion_matrix(train_labels,classes_x)
df_cm = pd.DataFrame(confusion_matrix,index = [ 'barrenland', 'builtup', 'fallowland','vegetation','wetland'],
                                                         columns = [ 'barrenland', 'builtup', 'fallowland','vegetation','wetland'])
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm,annot=True,fmt="d",cmap='Blues')
plt.title('4bandsCNNModel_trainingdata_ConfusionMatrix', fontsize =15) # title with fontsize 20
plt.xlabel('predicted Label', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('True Label', fontsize = 15) # y-axis label with fontsize 15
# Out:
# Text(41.24999999999999, 0.5, 'True Label')

# %%
#Testing data confusion matrix
# converts the one-hot encoded labels (y_test) into class indices
test_labels=np.argmax(y_test, axis=1)
predict_x=model_load.predict(X_test)
classes_x=np.argmax(predict_x,axis=1)
# Out:
# 94/94 [==============================] - 0s 3ms/step

# %%
# import necessary libraries for testing data confusion matrix
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# Testing data confusion matrix

confusion_matrix=confusion_matrix(test_labels,classes_x)

df_cm = pd.DataFrame(confusion_matrix,index = [ 'barrenland', 'builtup', 'fallowland','vegetation','wetland'],
                                                         columns = [ 'barrenland', 'builtup', 'fallowland','vegetation','wetland'])
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm,annot=True,fmt="d",cmap='Blues')
plt.title('4bandsCNNModel_testingdata_ConfusionMatrix', fontsize =15) # title with fontsize 20
plt.xlabel('predicted Label', fontsize = 15) # x-axis label with fontsize 15
plt.ylabel('True Label', fontsize = 15) # y-axis label with fontsize 15
# Out:
# Text(41.24999999999999, 0.5, 'True Label')

# %% [markdown]
# # Image Prediction with Trained CNN Model

# %% [markdown]
# Now, we will install the 'pyrsgis' library and load the Sentinel-2 multispectral image for classification using the trained CNN model

# %%
# install pyrsgis library
pip install pyrsgis

# %%
from pyrsgis import raster
import pyrsgis
import math

# %%
# Generate image patches in the back-end. This part is modified from https://towardsdatascience.com/is-cnn-equally-shiny-on-mid-resolution-satellite-data-9e24e68f0c08
ds, predict_raster = raster.read('/content/gdrive/MyDrive/LULC_DCNN/sentinel2image_Classification.tif')
def CNNdataGenerator(mxBands, kSize):
    mxBands = mxBands /65535.0
    nBands, rows, cols = mxBands.shape
    margin = math.floor(kSize/2)
    mxBands = np.pad(mxBands, margin, mode='constant')[2:-2, :, :]

    features = np.empty((rows*cols, kSize, kSize, nBands))

    n = 0
    for row in range(margin, rows+margin):
        for col in range(margin, cols+margin):
            feat = mxBands[:, row-margin:row+margin+1, col-margin:col+margin+1]

            b1, b2, b3, b4 = feat
            feat = np.dstack((b1, b2, b3, b4))

            features[n, :, :, :] = feat
            n += 1

    return(features)

# Call the function to generate features tensor
new_features = CNNdataGenerator( predict_raster, kSize=5)
print(new_features.shape)
print('Shape of the new features', new_features.shape)
# Out:
# (2331450, 5, 5, 4)
# Shape of the new features (2331450, 5, 5, 4)

# %%
# Predict new data
prediction= model_load .predict (new_features)
# Out:
# 72858/72858 [==============================] - 177s 2ms/step

# %%
# Converting predicted probabilities to class indices, The model's output, typically in the form of predicted probabilities for each class, needs to be converted into actual class predictions. argmax(axis=1) helps identify the index of the class with the highest predicted probability for each input sample.
pred = prediction.argmax(axis=1)

# %% [markdown]
# # Export the predicted classified raster

# %%
prediction = np.reshape(pred, (ds.RasterYSize, ds.RasterXSize))

outFile = '/content/gdrive/MyDrive/LULC_DCNN/sentinelimage_Classification.tif'
raster.export(prediction, ds, filename=outFile, dtype='float')

# %% [markdown]
# # Let's visualize it

# %% [markdown]
# I think this time, instead of using 'pyrsgis,' we should explore another geospatial library, 'Rasterio,' for the visualization of rasters.

# %%
# Let's print shape of multipspectral raster before visualization
print(predict_raster.shape)
# Out:
# (4, 1350, 1727)

# %%
pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.10/dist-packages (1.3.9)
# Requirement already satisfied: affine in /usr/local/lib/python3.10/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2023.11.17)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.23.5)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.1)

# %%
# Take our multispectral raster and reshape into long 2d array (nrow * ncol, nband) for visualization using Rasterio
from rasterio.plot import reshape_as_raster, reshape_as_image
reshaped_img = reshape_as_image(predict_raster)
print(reshaped_img.shape)
# Out:
# (1350, 1727, 4)

# %% [markdown]
# # Visualize multispectral and predicted classified raster

# %%
# import necessary libraries for visualization
import rasterio
from rasterio.plot import adjust_band
from matplotlib import patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.image

# Function for visualizing the original raster
def color_stretch(image, index):
    colors = image[:, :, index].astype(np.float64)
    for b in range(colors.shape[2]):
        colors[:, :, b] = adjust_band(colors[:, :, b])
    return colors

# Create colormap
clist = ["MediumTurquoise", "red", "Wheat", "LimeGreen", "Blue"]
cmap = matplotlib.colors.ListedColormap(clist)

# Define class names
class_names = ["Barren land", "Urban", "Fallow land", "Agriculture", "Wet land"]

# Create legend patches using class names
legend_patches = [mpatches.Patch(color=cmap(i), label=class_names[i]) for i in range(len(clist))]

# Visualize the original raster and the classified image
fig, axs = plt.subplots(1, 2, figsize=(20, 30))

img_stretched = color_stretch(reshaped_img, [3, 2, 1])
axs[0].imshow(img_stretched)
axs[0].set_axis_off()

axs[1].imshow(prediction, cmap=cmap, interpolation='none')
axs[1].set_axis_off()
axs[1].legend(handles=legend_patches, title='LULC_Classes', bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
